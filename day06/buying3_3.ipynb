# %%
# main/sub category 정보 수집

import requests
from bs4 import BeautifulSoup

res = requests.get("http://corners.gmarket.co.kr")

soup = BeautifulSoup(res.content, "html.parser")

categories = soup.select('div.gbest-cate ul.by-group li a')

'''
def get_items(html, category_name, sub_category_name):
    items_result_list = list()
    best_item = html.select('div.best-list')
    for idx, item in enumerate(best_item[1].select('li')):
        title = item.select_one('a.itemname')
        origin_price = item.select_one('div.o-price')
        discount_price = item.select_one('div.s-price strong span')
        discount_percent = item.select_one('div.s-price em')

        if origin_price == None or origin_price.get_text() == '':
            origin_price = discount_price

        origin_price = origin_price.get_text().replace(',','').replace('원','')
        discount_price = discount_price.get_text().replace(',','').replace('원','')

        if discount_percent == None or discount_percent == '':
            discount_percent = 0
        else:
            discount_percent = discount_percent.get_text().replace('%','')

        print(category_name, sub_category_name, title.get_text(), origin_price, discount_price, discount_percent) 
        
def get_category(category_link, category_name):
    res = requests.get(category_link)
    soup = BeautifulSoup(res.content, "html.parser")
    
    # print(category_link, category_name)
    
    # get_items(soup, category_name, "ALL")
    
    sub_categories = soup.select('div.gbest-cate div.cate-l div.navi.group ul li a')
    for sub_category in categories:
        res = requests.get('http://corners.gmarket.co.kr' + sub_category['href']) 
        soup = BeautifulSoup(res.content, 'html.parser')
        get_items(soup, category_name, sub_category.get_text())
        print(category_link, category_name, sub_category.get_text(), 'http://corners.gmarket.co.kr' + sub_category['href'])     

'''
for category in categories:
    # print('http://corners.gmarket.co.kr' + category['href'], category.get_text())    
    get_category('http://corners.gmarket.co.kr' + category['href'], category.get_text())
# Out:
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 1, 'title': 'PSK 항공 리얼 생 망고스틴 2kg(20-24과)', 'origin_price': '34900', 'discount_price': '32200', 'discount_percent': '7', 'item_code': '2144050371', 'provider': 'G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 2, 'title': '[제스프리](M)제스프리 썬골드키위 점보사이즈 3.1kg(과당 156g 내외  19-20과)', 'origin_price': '30900', 'discount_price': '28500', 'discount_percent': '7', 'item_code': '2132159697', 'provider': 'G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 3, 'title': '[KFC](KFC) 징거앤타워팩', 'origin_price': '22100', 'discount_price': '11500', 'discount_percent': '47', 'item_code': '2140618396', 'provider': 'G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 4, 'title': '[앱솔루트명작]앱솔루트 명작 3단계 800g 3캔 무료배송', 'origin_price': '44900', 'discount_price': '42900', 'discount_percent': '4', 'item_code': '1605671250', 'provider': 'G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 5, 'title': '[KB증권](KB증권) 국내주식 이용권 5만원권', 'origin_price': '50000', 'discount_price': '50000', 'discount_percent': 0, 'item_code': '2140383084', 'provider': 'G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 6, 'title': '완도 손질곰피미역 120gX5팩+갈치속젓', 'origin_price': '19800', 'discount_price': '9900', 'discount_percent': '50', 'item_code': '1760714599', 'provider': 'G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 7, 'title': '15%중복쿠폰/쿨레깅스/쿨팬츠/롱원피스/빅사이즈~4XL', 'origin_price': '23000', 'discount_price': '6900', 'discount_percent': '70', 'item_code': '1842357844', 'provider': 'G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 8, 'title': '[롯데제과]빼빼로(초코/아몬드/누드/크런키) 15곽 골라담기', 'origin_price': '17300', 'discount_price': '13900', 'discount_percent': '19', 'item_code': '2094678315', 'provider': 'G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 9, 'title': '[깨끗한나라]깨끗한나라 벚꽃 프리미엄 화장지 (총90롤) 27mx30롤', 'origin_price': '36810', 'discount_price': '30880', 'discount_percent': '16', 'item_code': '1932807663', 'provider': 'G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 10, 'title': '[동아오츠카]라인바싸 탄산수 500ml 2박스 ( 20입+20입 )', 'origin_price': '13900', 'discount_price': '13630', 'discount_percent': '1', 'item_code': '2127268043', 'provider': 'G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 11, 'title': '[참도깨비]춘천 식 숯불 닭갈비 750g x 2봉', 'origin_price': '23400', 'discount_price': '10500', 'discount_percent': '55', 'item_code': '2122431202', 'provider': '참도깨비'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 12, 'title': '[천하일미]홍석천 이원일 떡갈비 160g 전통3팩+매콤3팩 (총12장)', 'origin_price': '27800', 'discount_price': '12500', 'discount_percent': '55', 'item_code': '2094794152', 'provider': '천하일미'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 13, 'title': '[크록스]본사공식 크록스 BEST 29종 택 (G062121)', 'origin_price': '74950', 'discount_price': '22490', 'discount_percent': '69', 'item_code': '1205483415', 'provider': '스포츠의류/운동화 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 14, 'title': '수맘 여름 신상입고 15%쿠폰 면 홈웨어 잠옷 세트', 'origin_price': '19600', 'discount_price': '5900', 'discount_percent': '69', 'item_code': '1606293717', 'provider': '(수맘)'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 15, 'title': '[아이더](대구신세계)[아이더](역시즌추가할인)JMF19507 키즈 아동 큐빗 롱다운 롱패딩', 'origin_price': '63000', 'discount_price': '50340', 'discount_percent': '20', 'item_code': '1694504111', 'provider': '유아동의류 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 16, 'title': '[다우니]1+1 다우니 프리미엄 폼형 세제 실내건조 16입 +사은품', 'origin_price': '51900', 'discount_price': '38930', 'discount_percent': '24', 'item_code': '1837778618', 'provider': '다우니'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 17, 'title': '[애플][국내정품] 애플 에어팟 프로 무선 충전 MWP22KH/A', 'origin_price': '297000', 'discount_price': '252450', 'discount_percent': '15', 'item_code': '2107124794', 'provider': '음향기기 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 18, 'title': '[스카치 브라이트]베이직 고무장갑 10개 사이즈 선택+집게 증정', 'origin_price': '31800', 'discount_price': '15900', 'discount_percent': '50', 'item_code': '1502601299', 'provider': '주방용품 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 19, 'title': '[늘바른]이베리코 양념 치마살1kg /2세트구매국산오돌뼈500g증', 'origin_price': '21900', 'discount_price': '10900', 'discount_percent': '50', 'item_code': '2140324687', 'provider': '가공식품 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 20, 'title': '소불고기 광양식 250gX3팩/수제비법소스의 깊은 감칠맛', 'origin_price': '22000', 'discount_price': '9900', 'discount_percent': '55', 'item_code': '2135847830', 'provider': '엉클탐'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 21, 'title': '[구글플레이](카드가능) 기프트코드 10만원 / 구글 기프트카드', 'origin_price': '100000', 'discount_price': '95000', 'discount_percent': '5', 'item_code': '1655242371', 'provider': 'e쿠폰 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 22, 'title': '[스카트]스카트 THE 버블 수세미 그레이 50매X3롤', 'origin_price': '27000', 'discount_price': '11900', 'discount_percent': '55', 'item_code': '1791759756', 'provider': '스카트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 23, 'title': '[이너리즘]심리스 스포츠 브라탑 4종기획세트/노라인팬티 5종', 'origin_price': '45000', 'discount_price': '13500', 'discount_percent': '70', 'item_code': '1624900645', 'provider': '언더웨어 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 24, 'title': '[KFC](KFC) 더블치킨세트', 'origin_price': '12000', 'discount_price': '6000', 'discount_percent': '50', 'item_code': '2140616286', 'provider': 'e쿠폰 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 25, 'title': '쉬블림로브 15%쿠폰 균일가 블라우스 셔츠 상하세트', 'origin_price': '29600', 'discount_price': '8900', 'discount_percent': '69', 'item_code': '1373777190', 'provider': '쉬블림로브'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 26, 'title': '티메이 15%할인 블라우스 원피스 티셔츠 반팔', 'origin_price': '32900', 'discount_price': '9900', 'discount_percent': '69', 'item_code': '1280233513', 'provider': 'T-MEI'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 27, 'title': '[참도깨비]금강만두 육개장 630g x5봉', 'origin_price': '33900', 'discount_price': '16900', 'discount_percent': '50', 'item_code': '2122330900', 'provider': '참도깨비'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 28, 'title': '2021년 첫 출하 의성 군위 대석 자두 3kg/소과 25-40g내외', 'origin_price': '11500', 'discount_price': '10350', 'discount_percent': '10', 'item_code': '2137965030', 'provider': '멸치쇼핑'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 29, 'title': '[컬럼비아](광주신세계)컬럼비아 남성 팔머스톤 기능성 반바지(AE4366)', 'origin_price': '30000', 'discount_price': '24000', 'discount_percent': '20', 'item_code': '1808836883', 'provider': '등산/아웃도어 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 30, 'title': '[다우니]다우니 프리미엄 액체형 세탁세제 실내건조 2.8L 2개', 'origin_price': '32900', 'discount_price': '24680', 'discount_percent': '24', 'item_code': '1837767492', 'provider': '다우니'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 31, 'title': '[브라운](현대백화점)브라운 3시리즈 전기면도기 310S', 'origin_price': '47700', 'discount_price': '44840', 'discount_percent': '5', 'item_code': '2124077426', 'provider': '브라운'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 32, 'title': '[한국투자증권](한국투자증권) 온라인 금융상품권 50000원권', 'origin_price': '50000', 'discount_price': '50000', 'discount_percent': 0, 'item_code': '2118721967', 'provider': 'e쿠폰 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 33, 'title': '[드시모네]베이비 캡슐 2박스 + 6일분 추가증정', 'origin_price': '76000', 'discount_price': '76000', 'discount_percent': 0, 'item_code': '1645930937', 'provider': '건강식품 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 34, 'title': '[KB증권](KB증권) 국내주식 이용권 1만원권', 'origin_price': '10000', 'discount_price': '10000', 'discount_percent': 0, 'item_code': '2140381723', 'provider': 'KB증권'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 35, 'title': '필리핀/ 5봉 사바나나 바나나칩 사바나나칩 간식 과자', 'origin_price': '21800', 'discount_price': '10900', 'discount_percent': '50', 'item_code': '1107732299', 'provider': '365쿠키세일'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 36, 'title': '[푸마]4차앵콜행사 푸마 남녀 반팔티셔츠/쿨링 냉감 티셔츠', 'origin_price': '43000', 'discount_price': '12900', 'discount_percent': '70', 'item_code': '1857602303', 'provider': '골프 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 37, 'title': '모노시크/15%/티셔츠/신상/데일리/루즈핏/빅사이즈', 'origin_price': '26300', 'discount_price': '7900', 'discount_percent': '69', 'item_code': '2128333213', 'provider': '여성의류 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 38, 'title': '[헤이미니]15%쿠폰/썸머세일/원피스/상하복/티셔츠/유아동', 'origin_price': '23000', 'discount_price': '6900', 'discount_percent': '70', 'item_code': '2057180438', 'provider': '헤이미니'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 39, 'title': 'BB LAB 저분자콜라겐 3통(3개월분)', 'origin_price': '48970', 'discount_price': '43350', 'discount_percent': '11', 'item_code': '1829770933', 'provider': '건강식품 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 40, 'title': '[아이더]갤러리아   2021년 출시제품  EIDER 2 PACK SERIES DMM21270', 'origin_price': '32000', 'discount_price': '24000', 'discount_percent': '25', 'item_code': '1762666926', 'provider': '등산/아웃도어 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 41, 'title': '밥상마루 100% 참기름 350ml 1+1', 'origin_price': '20900', 'discount_price': '15900', 'discount_percent': '23', 'item_code': '2130196344', 'provider': '광천다솔김'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 42, 'title': '15%쿠폰/아이스냉감/스판/린넨/트레이닝바지/반바지', 'origin_price': '36000', 'discount_price': '10800', 'discount_percent': '70', 'item_code': '2092808430', 'provider': '남성의류 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 43, 'title': '엘다 에비히 IH후라이팬 1+1', 'origin_price': '49900', 'discount_price': '16900', 'discount_percent': '66', 'item_code': '2112964328', 'provider': '두리몽'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 44, 'title': '[팍티오]15%쿠폰/여름빅세일/2장이상구입시 팬티사은품/무배', 'origin_price': '22300', 'discount_price': '8900', 'discount_percent': '60', 'item_code': '1345137474', 'provider': '팍티오'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 45, 'title': '[나우푸드](아이허브) 2개X Now Foods L-아르기닌 더블 스트렝스 1 000mg 120정 빠른직구', 'origin_price': '39200', 'discount_price': '32940', 'discount_percent': '15', 'item_code': '2037313786', 'provider': '나우푸드'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 46, 'title': '[양말폭탄]여름 아동양말 신상 특가 덧신/메시양말/스니커즈', 'origin_price': '16300', 'discount_price': '4900', 'discount_percent': '69', 'item_code': '1536590878', 'provider': '유아동신발/잡화 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 47, 'title': '[행텐틴즈]최대15%+17%할인/주니어여름신상입고BEST상품 특가전', 'origin_price': '26300', 'discount_price': '7900', 'discount_percent': '69', 'item_code': '1806544358', 'provider': '유아동의류 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 48, 'title': '[해피바스]오늘하루 아모레퍼시픽 데일리뷰티 특가', 'origin_price': '23000', 'discount_price': '10900', 'discount_percent': '52', 'item_code': '2136632716', 'provider': '화장품/향수 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 49, 'title': '[네파키즈](신세계타임스퀘어점패션관)신상품 기능성티셔츠 3종세트 or 기능성바지 2종세트 KHG5300', 'origin_price': '29000', 'discount_price': '22040', 'discount_percent': '24', 'item_code': '2057706892', 'provider': '네파 키즈'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 50, 'title': '[베베앙]베베앙 아기물티슈  시그니처 대용량 100매 캡형 10팩', 'origin_price': '35700', 'discount_price': '11900', 'discount_percent': '66', 'item_code': '1604479096', 'provider': '생필품 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 51, 'title': '[릴리유]릴리유 퓨어퍼플 물티슈 캡72매X10팩(1BOX)', 'origin_price': '27000', 'discount_price': '16900', 'discount_percent': '37', 'item_code': '1766184747', 'provider': '생필품 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 52, 'title': '[베이비베이비]베이비베이비 아기물티슈 트윙클120매 20팩 캡형', 'origin_price': '44700', 'discount_price': '14900', 'discount_percent': '66', 'item_code': '1501667618', 'provider': '베이비베이비공식'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 53, 'title': '[아디다스]아디다스/나이키 힙색/보조가방/팀백/여행가방 42종', 'origin_price': '59600', 'discount_price': '17900', 'discount_percent': '69', 'item_code': '177482771', 'provider': '스포츠의류/운동화 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 54, 'title': '3SK BOX 택배박스 업계를 리드하는 기업', 'origin_price': '35300', 'discount_price': '35300', 'discount_percent': 0, 'item_code': '161267854', 'provider': '문구/사무용품 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 55, 'title': '[쏘피]볼록맞춤 슈퍼롱 오버나이트/생리대 10Px5팩+볼록16P', 'origin_price': '17800', 'discount_price': '8900', 'discount_percent': '50', 'item_code': '1140168037', 'provider': '쏘피'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 56, 'title': '[이엑스알]EXR 21SS 남성용 멀티웨어 5종', 'origin_price': '29000', 'discount_price': '28000', 'discount_percent': '3', 'item_code': '2134598627', 'provider': '이엑스알'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 57, 'title': '[이블랑]시어서커/인견/60수아사/모달와플/피그먼트 여름침구', 'origin_price': '72900', 'discount_price': '25500', 'discount_percent': '65', 'item_code': '1808987107', 'provider': '침구/커튼 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 58, 'title': '[오뚜기밥]오뚜기 작은밥 150G 30개', 'origin_price': '37900', 'discount_price': '25900', 'discount_percent': '31', 'item_code': '2051351940', 'provider': '오뚜기공식'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 59, 'title': '양희경 서울식 포기김치 10Kg/국내산', 'origin_price': '44200', 'discount_price': '30900', 'discount_percent': '30', 'item_code': '1278311858', 'provider': '김나운더키친'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 60, 'title': '[3M]크린스틱 변기청소 핸들+리필 베이킹소다 21입+사은품', 'origin_price': '31800', 'discount_price': '14310', 'discount_percent': '55', 'item_code': '1180471256', 'provider': '생활용품 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 61, 'title': '[KFC](KFC) 핫통베이컨치킨세트 / 6월22일부터 사용가능', 'origin_price': '11400', 'discount_price': '6300', 'discount_percent': '44', 'item_code': '2140601894', 'provider': 'KFC'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 62, 'title': '[퍼펙트바이오틱스]W프로바이오틱스 여성 질유래유산균 신바이오틱스 5box', 'origin_price': '23900', 'discount_price': '23900', 'discount_percent': 0, 'item_code': '1820928270', 'provider': '퍼펙트바이오틱스공식'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 63, 'title': '두메산골 닭볶음탕용 냉장 닭 절단육 1kg+1kg (총 2kg)', 'origin_price': '19800', 'discount_price': '9900', 'discount_percent': '50', 'item_code': '2131441339', 'provider': '테미즈'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 64, 'title': '[일리윤](한정수량 1000개)일리윤 스킨베리어 여성청결제 50ml', 'origin_price': '2500', 'discount_price': '2500', 'discount_percent': 0, 'item_code': '2133780933', 'provider': '바디/헤어 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 65, 'title': '[제주삼다수]제주삼다수 500ml 40병 /생수전문배송', 'origin_price': '26200', 'discount_price': '17000', 'discount_percent': '35', 'item_code': '2084163304', 'provider': '커피/음료 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 66, 'title': '[앱솔루트명작]앱솔루트 명작 4단계 800g 3캔 무료배송', 'origin_price': '45300', 'discount_price': '43300', 'discount_percent': '4', 'item_code': '1636344550', 'provider': '매일유업공식'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 67, 'title': '[유한락스]유한락스 new 욕실청소 500mlx4개', 'origin_price': '16900', 'discount_price': '11900', 'discount_percent': '29', 'item_code': '1305930185', 'provider': '유한락스'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 68, 'title': '[현대]오늘 천연펄프100% 키친타올 125매 4롤 4개 화장지', 'origin_price': '11900', 'discount_price': '11900', 'discount_percent': 0, 'item_code': '2129169607', 'provider': '현대'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 69, 'title': '[센스(물티슈)]센스물티슈 악어 캡형 100매 10팩+10팩', 'origin_price': '40500', 'discount_price': '13500', 'discount_percent': '66', 'item_code': '1490019603', 'provider': '생필품 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 70, 'title': '[KFC](KFC) 2만원권', 'origin_price': '20000', 'discount_price': '17800', 'discount_percent': '11', 'item_code': '2140597078', 'provider': 'KFC'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 71, 'title': '한우떡갈비식구이 290g1팩(4장)x3팩', 'origin_price': '14200', 'discount_price': '9900', 'discount_percent': '30', 'item_code': '671320650', 'provider': '홍천한우마을'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 72, 'title': '[구글플레이](카드가능) 기프트코드 5만원 / 구글 기프트카드', 'origin_price': '50000', 'discount_price': '47500', 'discount_percent': '5', 'item_code': '1655242060', 'provider': 'e쿠폰 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 73, 'title': '[맥심]모카골드 커피믹스 180T+180T /쿠폰36500', 'origin_price': '56500', 'discount_price': '39500', 'discount_percent': '30', 'item_code': '1103681365', 'provider': '커피/음료 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 74, 'title': '쇼인더룸 15%쿠폰특가 여름신상 티셔츠/팬츠/빅사이즈', 'origin_price': '42900', 'discount_price': '12900', 'discount_percent': '69', 'item_code': '1975776752', 'provider': '여성의류 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 75, 'title': '[아이러브베베]아이러브베베물티슈핑크100매캡형X20팩', 'origin_price': '27800', 'discount_price': '13900', 'discount_percent': '50', 'item_code': '1124083462', 'provider': '아이러브베베'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 76, 'title': '[하비비]청개구리 자동 변기 클리너 세정제 6개 (12개월분)', 'origin_price': '59700', 'discount_price': '19900', 'discount_percent': '66', 'item_code': '1583809257', 'provider': '하비비공식'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 77, 'title': '농협 옹골찬 신비복숭아 3kg GAP 특등급', 'origin_price': '49900', 'discount_price': '49900', 'discount_percent': 0, 'item_code': '2143075223', 'provider': 'CJ온스타일플러스'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 78, 'title': '국내생산-엄마랑 세이펜 포스터 병풍 12장분 만들기 당일발송', 'origin_price': '66000', 'discount_price': '47800', 'discount_percent': '27', 'item_code': '2088452276', 'provider': '훈민출판사'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 79, 'title': '[이지바이](15%쿠폰)스포츠/아웃도어 균일/반팔티/추리닝/바지', 'origin_price': '26600', 'discount_price': '8000', 'discount_percent': '69', 'item_code': '1498699891', 'provider': '남성의류 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 80, 'title': '[한국투자증권](한국투자증권) 온라인 금융상품권 3만원권', 'origin_price': '30000', 'discount_price': '30000', 'discount_percent': 0, 'item_code': '2139714686', 'provider': 'e쿠폰 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 81, 'title': '[엄마애바다]엄마애바다 디포리다시팩 1+1', 'origin_price': '17800', 'discount_price': '8900', 'discount_percent': '50', 'item_code': '1640128544', 'provider': '엄마애바다'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 82, 'title': '[HP]HP A4 복사용지(A4용지) 80g 2500매 2BOX (5000매)', 'origin_price': '38250', 'discount_price': '32900', 'discount_percent': '13', 'item_code': '782096663', 'provider': '문구/사무용품 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 83, 'title': '[바이오가이아](아이허브) 2개X 바이오가이아 아기 유산균 프로텍티스 베이비드롭 비타민 D 함유 10ml 빠른직구', 'origin_price': '70000', 'discount_price': '59500', 'discount_percent': '15', 'item_code': '2037310581', 'provider': '건강식품 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 84, 'title': '(행사상품)N 동서식품_맥심모카골드믹스_230T 2760G ', 'origin_price': '22900', 'discount_price': '22450', 'discount_percent': '1', 'item_code': '1273999192', 'provider': '홈플러스당일배송'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 85, 'title': '[제주삼다수]제주삼다수 2L 12병 /생수전문배송', 'origin_price': '18000', 'discount_price': '11900', 'discount_percent': '33', 'item_code': '2084149868', 'provider': '커피/음료 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 86, 'title': '여름파자마 총집합/인견/엠보/지지미/시어커/레이온', 'origin_price': '19600', 'discount_price': '5900', 'discount_percent': '69', 'item_code': '949976014', 'provider': '언더웨어 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 87, 'title': '1+1 K2 Safety X밴더 쿨토시 손등형 팔토시  NEW 2021', 'origin_price': '11900', 'discount_price': '11670', 'discount_percent': '1', 'item_code': '2079794399', 'provider': '공구/안전/산업용품 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 88, 'title': '[락토핏]15% 락토핏 5X 생유산균 골드 50포 3통(150일분)', 'origin_price': '45900', 'discount_price': '42900', 'discount_percent': '6', 'item_code': '1577510972', 'provider': '건강식품 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 89, 'title': '[윈드피아]가정용 업소용 사무실 스탠드 키높이 선풍기 WA-170', 'origin_price': '27900', 'discount_price': '23720', 'discount_percent': '14', 'item_code': '1812561991', 'provider': '계절가전 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 90, 'title': '다온샵/여름신상15% 빅사이즈/데님/슬랙스/린넨/스판', 'origin_price': '33000', 'discount_price': '9900', 'discount_percent': '70', 'item_code': '373058782', 'provider': '다온샵.'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 91, 'title': '홈쇼핑히트 21S/S 블라우스/원피스/티셔츠/팬츠 外', 'origin_price': '49600', 'discount_price': '14900', 'discount_percent': '69', 'item_code': '1764397632', 'provider': '여성의류 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 92, 'title': '[아침농산]국산 농부의아침 쌀10kg  2020년산', 'origin_price': '29900', 'discount_price': '29520', 'discount_percent': '1', 'item_code': '484828506', 'provider': '신선식품 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 93, 'title': '더빨강양말 남자여자 덧신/발목/중목/장목/학생 양말', 'origin_price': '23000', 'discount_price': '6900', 'discount_percent': '70', 'item_code': '1491799783', 'provider': '가방/잡화 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 94, 'title': '[하이드로더치]하이드로 더치커피 콜드브루 원두 30ml 8종 10+10+7팩', 'origin_price': '5600', 'discount_price': '3900', 'discount_percent': '30', 'item_code': '1333899282', 'provider': '커피/음료 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 95, 'title': '고등어 70-100g x 20팩', 'origin_price': '22800', 'discount_price': '15900', 'discount_percent': '30', 'item_code': '2075015596', 'provider': '스마일배송'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 96, 'title': '2021 제주 햇 초당 옥수수 20개', 'origin_price': '27400', 'discount_price': '27400', 'discount_percent': 0, 'item_code': '2131417218', 'provider': 'NS홈쇼핑'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 97, 'title': '[미래생활]미래생활 순수PURE천연펄프 25m 30롤 x 3팩', 'origin_price': '31900', 'discount_price': '26900', 'discount_percent': '15', 'item_code': '1899274105', 'provider': '생필품 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 98, 'title': '[트라이]아동팬티 5매 세트 /남아/여아/속옷/런닝/유아/주니어', 'origin_price': '23000', 'discount_price': '6900', 'discount_percent': '70', 'item_code': '185126914', 'provider': '트라이'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 99, 'title': '대한농산 천도 복숭아 3kg내외(40과내외)', 'origin_price': '9900', 'discount_price': '9710', 'discount_percent': '1', 'item_code': '2140732651', 'provider': '대한농산(G)'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 100, 'title': '[러브쿡]스텐 국수냄비 18cm (깊은형)/ 파스타냄비 육수냄비', 'origin_price': '19800', 'discount_price': '9900', 'discount_percent': '50', 'item_code': '1828312825', 'provider': '러브쿡'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 101, 'title': '[크리넥스]크리넥스 실크소프트 250매X3입X3팩 /곽티슈', 'origin_price': '27000', 'discount_price': '16900', 'discount_percent': '37', 'item_code': '1797053808', 'provider': '생필품 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 102, 'title': '국산 10켤레 남자양말 패션 발목 덧신 중목 신사 정장', 'origin_price': '21000', 'discount_price': '6400', 'discount_percent': '69', 'item_code': '1487777111', 'provider': '가방/잡화 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 103, 'title': '[리챔]리챔 200g x 10캔 + 리챔 120g x 1캔', 'origin_price': '20780', 'discount_price': '18700', 'discount_percent': '10', 'item_code': '1909900945', 'provider': '동원에프앤비공식'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 104, 'title': '[크리넥스안심]유한킴벌리 안심 클래식 키친타올 140매x12롤X2팩', 'origin_price': '27000', 'discount_price': '18900', 'discount_percent': '30', 'item_code': '1783303725', 'provider': '크리넥스'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 105, 'title': '[드시모네]캡슐 1박스 60캡슐(2개월분)', 'origin_price': '118000', 'discount_price': '118000', 'discount_percent': 0, 'item_code': '1645927108', 'provider': '드시모네공식'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 106, 'title': '[진라면]진라면 순한맛 20봉+매운맛20봉', 'origin_price': '30000', 'discount_price': '18800', 'discount_percent': '37', 'item_code': '1614192635', 'provider': '오뚜기공식'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 107, 'title': '[밀레](대구신세계)[밀레]역시즌 여성 폭스퍼 셀레네W 구스 다운(MXPWD663)[출시 최초가 388 000원]', 'origin_price': '99000', 'discount_price': '74250', 'discount_percent': '25', 'item_code': '2135690531', 'provider': '밀레'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 108, 'title': '[천호엔케어]콜라겐 담은 석류젤리 14포x4박스 총56포/장윤정콜라겐', 'origin_price': '53000', 'discount_price': '29900', 'discount_percent': '43', 'item_code': '1827756830', 'provider': '천호엔케어공식'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 109, 'title': '[아디다스키즈](신세계강남점)[adidas kidss]SUPERSTAR 360 I(Q46306)', 'origin_price': '59000', 'discount_price': '44840', 'discount_percent': '24', 'item_code': '2137892100', 'provider': '아디다스키즈'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 110, 'title': '[더틸버리](더틸버리) 오버핏 체크 시어서커 원피스 TL6N0OP62', 'origin_price': '31200', 'discount_price': '31200', 'discount_percent': 0, 'item_code': '2104309832', 'provider': '더틸버리'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 111, 'title': '보가수제화 여름 신상 샌들/뮬/슬리퍼/조리', 'origin_price': '33000', 'discount_price': '9900', 'discount_percent': '70', 'item_code': '1765233891', 'provider': '신발 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 112, 'title': '[칠성사이다]칠성 사이다 210ml x 30캔', 'origin_price': '15900', 'discount_price': '11500', 'discount_percent': '27', 'item_code': '1578966236', 'provider': '롯데칠성공식'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 113, 'title': '[레노마키즈]레노마키즈 페리미츠 여름 이월 티셔츠 팬츠 70종', 'origin_price': '33000', 'discount_price': '10000', 'discount_percent': '69', 'item_code': '2104253380', 'provider': '레노마키즈공식'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 114, 'title': '국내산 무형광천연펄프 엑소 종이컵 1000개  사업자', 'origin_price': '11000', 'discount_price': '11000', 'discount_percent': 0, 'item_code': '1747435299', 'provider': '스마일배송'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 115, 'title': '[유한킴벌리]크리넥스 비말차단 라이트핏 쿨마스크 대형 50p(1BOX)', 'origin_price': '39900', 'discount_price': '26900', 'discount_percent': '32', 'item_code': '2133708741', 'provider': '건강/의료용품 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 116, 'title': '[햇반](빠른배송) CJ 햇반 190g 36개', 'origin_price': '32700', 'discount_price': '32100', 'discount_percent': '1', 'item_code': '2110863137', 'provider': '신세계TV쇼핑'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 117, 'title': '[과일나라]진주펄 염색약 3개 /12종 컬러 염색/새치/탈색약', 'origin_price': '28900', 'discount_price': '8900', 'discount_percent': '69', 'item_code': '1289510185', 'provider': '바디/헤어 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 118, 'title': '[글라스락]글라스락 간편쿡용기 1.2L 2조', 'origin_price': '29800', 'discount_price': '14900', 'discount_percent': '50', 'item_code': '1911171606', 'provider': '글라스락공식'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 119, 'title': '순살 치킨 가라아게1kg / 치킨/너겟/간식 1+1 (총2kg)', 'origin_price': '28700', 'discount_price': '12900', 'discount_percent': '55', 'item_code': '1558860840', 'provider': '슈퍼맨푸드'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 120, 'title': '신상 여성샌들 여성슬리퍼 여자 샌들 슬리퍼 여름샌들', 'origin_price': '33000', 'discount_price': '9900', 'discount_percent': '70', 'item_code': '1808857191', 'provider': '신발 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 121, 'title': '[아워홈]지리산수 핑크 500ml 80병 /생수전문배송', 'origin_price': '24500', 'discount_price': '15840', 'discount_percent': '35', 'item_code': '2084042826', 'provider': '아워홈'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 122, 'title': '[아워홈]지리산수 핑크 500ml 20병 /생수전문배송', 'origin_price': '6100', 'discount_price': '3970', 'discount_percent': '34', 'item_code': '2084038788', 'provider': '커피/음료 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 123, 'title': '[유한킴벌리]크리넥스3겹 데코소프트33MX24롤X2팩', 'origin_price': '49000', 'discount_price': '32900', 'discount_percent': '32', 'item_code': '2095685860', 'provider': '유한킴벌리공식'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 124, 'title': '로코코  15% 여름신상 원피스/블라우스', 'origin_price': '33000', 'discount_price': '9900', 'discount_percent': '70', 'item_code': '2128272385', 'provider': '여성의류 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 125, 'title': '[에뛰드]6월 SALE 순정 40% 메이크업 50%', 'origin_price': '50000', 'discount_price': '25000', 'discount_percent': '50', 'item_code': '2001447494', 'provider': '화장품/향수 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 126, 'title': '말랑말랑 컬러 실내 쿠션 슬리퍼 1+1 거실화/욕실화', 'origin_price': '33000', 'discount_price': '9900', 'discount_percent': '70', 'item_code': '2060835461', 'provider': '신발 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 127, 'title': '[구글플레이](카드가능) 기프트코드 3만원 / 구글 기프트카드', 'origin_price': '30000', 'discount_price': '28500', 'discount_percent': '5', 'item_code': '1655241628', 'provider': '구글플레이'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 128, 'title': '[맥심]모카골드 커피믹스 180T+180T : 쿠폰가 36500원~', 'origin_price': '56500', 'discount_price': '39500', 'discount_percent': '30', 'item_code': '1920642031', 'provider': '맥심'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 129, 'title': '[헬로]헬로 순수 3겹 천연펄프 화장지 30m 30롤 3팩 특가행사', 'origin_price': '86700', 'discount_price': '28900', 'discount_percent': '66', 'item_code': '1821519273', 'provider': '헬로공식'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 130, 'title': '[맥심]화이트골드 커피믹스 180Tx2 +사은품랜덤/쿠폰가34500', 'origin_price': '53600', 'discount_price': '37500', 'discount_percent': '30', 'item_code': '1103688403', 'provider': '맥심'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 131, 'title': '[강블리]블링 휴 3겹 무형광 롤화장지 30M 30롤 2팩', 'origin_price': '47700', 'discount_price': '15900', 'discount_percent': '66', 'item_code': '1583658466', 'provider': '강블리'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 132, 'title': '[스와들업] 신생아 속싸개 뱀부라이트_가볍고부드러운 뱀부원단', 'origin_price': '68000', 'discount_price': '38900', 'discount_percent': '42', 'item_code': '801692869', 'provider': 'CJ온스타일'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 133, 'title': '[세타필]세타필 대용량1+1(로션 473ml+로션 473ml) +사은품3종', 'origin_price': '39000', 'discount_price': '23900', 'discount_percent': '38', 'item_code': '1505743733', 'provider': '바디/헤어 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 134, 'title': '[프로베스트]프로베스트캣 블루 20kg  / 무료배송 / 박스포장', 'origin_price': '31500', 'discount_price': '31500', 'discount_percent': 0, 'item_code': '1464560778', 'provider': '반려동물용품 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 135, 'title': '[드시모네]키즈 스텝1 블루베리  1박스 30포(30일분)', 'origin_price': '68000', 'discount_price': '68000', 'discount_percent': 0, 'item_code': '1645922945', 'provider': '드시모네공식'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 136, 'title': '하림이닭 삼계탕 6팩', 'origin_price': '45900', 'discount_price': '45900', 'discount_percent': 0, 'item_code': '2140489832', 'provider': 'NS홈쇼핑'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 137, 'title': '[프롬산타]3+1 봄 신상 면 덧신/양말/스타킹 남자여자발목학생', 'origin_price': '23000', 'discount_price': '6900', 'discount_percent': '70', 'item_code': '1277558140', 'provider': '가방/잡화 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 138, 'title': '[행텐]누구나17% 행텐 루니툰즈티셔츠독점판매+최대90%SALE', 'origin_price': '29600', 'discount_price': '8900', 'discount_percent': '69', 'item_code': '1917857271', 'provider': '브랜드 진/캐쥬얼 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 139, 'title': '2박스 대용량 커피크래커 커피과자 쿠키', 'origin_price': '10900', 'discount_price': '8900', 'discount_percent': '18', 'item_code': '1704376711', 'provider': '스마일배송'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 140, 'title': '파스쿠찌 쿨링백 증정  파스쿠찌 커피 6입 택1 아메리카노/라떼', 'origin_price': '15900', 'discount_price': '15900', 'discount_percent': 0, 'item_code': '2139641345', 'provider': 'CJ온스타일'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 141, 'title': '쿠폰15% 원피스/블라우스/여름니트/가디건 빅사이즈', 'origin_price': '33000', 'discount_price': '9900', 'discount_percent': '70', 'item_code': '1517719492', 'provider': '메이킹유'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 142, 'title': '[동원에프앤비](현대Hmall)[동원]샘물 2L x 총 36병 /생수', 'origin_price': '17900', 'discount_price': '17640', 'discount_percent': '1', 'item_code': '983183427', 'provider': '현대Hmall'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 143, 'title': '[비룡소]비룡소 사각사각 그림책 (전25권)', 'origin_price': '265770', 'discount_price': '239200', 'discount_percent': '9', 'item_code': '1946636544', 'provider': '비룡소'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 144, 'title': '[카누]카누 미니 마일드 120Tx2개 총240T: 공유의 작은카페~', 'origin_price': '49900', 'discount_price': '34900', 'discount_percent': '30', 'item_code': '447292392', 'provider': '맥심'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 145, 'title': '[맥심]맥심 모카골드 마일드 180T+180T +텀블러+쿠폰가36500', 'origin_price': '56500', 'discount_price': '39500', 'discount_percent': '30', 'item_code': '1780733427', 'provider': '맥심'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 146, 'title': '[다우니]다우니 엑스퍼트 실내 건조 1L 6개 +사은품', 'origin_price': '39800', 'discount_price': '31840', 'discount_percent': '20', 'item_code': '1817538454', 'provider': '다우니'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 147, 'title': '[타미힐피거]타미힐피거 여성 카라 민소매 원피스 7종', 'origin_price': '41500', 'discount_price': '12450', 'discount_percent': '70', 'item_code': '2096204420', 'provider': '타미힐피거'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 148, 'title': '[드시모네]베이비 캡슐 1박스(30일분)', 'origin_price': '38000', 'discount_price': '38000', 'discount_percent': 0, 'item_code': '1645917783', 'provider': '드시모네공식'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 149, 'title': '(누리푸드)한번도 얼리지않은 눈꽃살치살 250gX2팩', 'origin_price': '25600', 'discount_price': '17900', 'discount_percent': '30', 'item_code': '2104268165', 'provider': '누리푸드'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 150, 'title': '[매일유업]매일두유 고단백 190ml 48팩 +포토카드', 'origin_price': '33500', 'discount_price': '26500', 'discount_percent': '20', 'item_code': '2122075872', 'provider': '매일유업공식'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 151, 'title': '(명왕성은자유다) 수학식당 시리즈 (전3권)', 'origin_price': '36000', 'discount_price': '33600', 'discount_percent': '6', 'item_code': '2134680693', 'provider': '테마북짱'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 152, 'title': '무형광 5000매핸드타올 C 업소용 가정용 다용도 대용량', 'origin_price': '21120', 'discount_price': '21120', 'discount_percent': 0, 'item_code': '1757179931', 'provider': '숲속의하루'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 153, 'title': '[박스포유]100%직접생산/ 박스포유 택배박스', 'origin_price': '32300', 'discount_price': '29840', 'discount_percent': '7', 'item_code': '153279336', 'provider': '문구/사무용품 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 154, 'title': '데이데이 생리대 롱팬티라이너 16p x6팩', 'origin_price': '12800', 'discount_price': '3900', 'discount_percent': '69', 'item_code': '2088091398', 'provider': '리빙amc'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 155, 'title': '브리치X저스트원 BEST 15%쿠폰 셔츠/팬츠/스커트', 'origin_price': '44600', 'discount_price': '13400', 'discount_percent': '69', 'item_code': '2104368705', 'provider': 'brich'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 156, 'title': '홈쇼핑 썸머세일 린넨/원피스/티셔츠 4900~', 'origin_price': '33000', 'discount_price': '9900', 'discount_percent': '70', 'item_code': '1383578038', 'provider': '여성의류 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 157, 'title': '[슈프림]15%쿠폰 오버핏 반팔티 남성티셔츠 남자여성 빅사이즈', 'origin_price': '29600', 'discount_price': '8900', 'discount_percent': '69', 'item_code': '805485741', 'provider': '남성의류 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 158, 'title': '[코디]허브가든 3겹 화장지 27m 30롤 3팩 휴지', 'origin_price': '83100', 'discount_price': '27700', 'discount_percent': '66', 'item_code': '1779187574', 'provider': '코디공식'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 159, 'title': '황금미가 쌀 20kg 20년산 (당일도정)', 'origin_price': '58900', 'discount_price': '54900', 'discount_percent': '6', 'item_code': '858294811', 'provider': '홍천철원물류센터2'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 160, 'title': '[오뚜기밥]맛있는 오뚜기밥 210g 24개', 'origin_price': '31900', 'discount_price': '28280', 'discount_percent': '11', 'item_code': '1503353718', 'provider': '오뚜기공식'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 161, 'title': '[GS수퍼마켓](GS THE FRESH)금액상품권3만원', 'origin_price': '30000', 'discount_price': '28500', 'discount_percent': '5', 'item_code': '1536107828', 'provider': 'GS수퍼마켓'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 162, 'title': '[GNM자연의품격]칼슘 마그네슘 아연 비타민D 2통/6개월분', 'origin_price': '25900', 'discount_price': '19900', 'discount_percent': '23', 'item_code': '1567169398', 'provider': 'GNM자연의품격공식'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 163, 'title': '[미스터카피]미스터카피 A4 복사용지 A4용지 75g 2500매 2박스', 'origin_price': '34760', 'discount_price': '29900', 'discount_percent': '13', 'item_code': '1495296156', 'provider': '미스터카피'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 164, 'title': '[카누]카누 미니 마일드 120Tx2개 240T/커피믹스/아메리카노', 'origin_price': '49900', 'discount_price': '34900', 'discount_percent': '30', 'item_code': '1687622836', 'provider': '맥심'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 165, 'title': '[리르]1+1+1 리르 포크 타투아이브로우 틴트', 'origin_price': '36000', 'discount_price': '10900', 'discount_percent': '69', 'item_code': '1918826332', 'provider': '리르공식'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 166, 'title': '[블랙야크키즈](신세계센텀점)[블랙야크키즈]21년 여름 반팔 쿨 상하복세트 3종1택', 'origin_price': '39000', 'discount_price': '29640', 'discount_percent': '24', 'item_code': '2128525773', 'provider': '유아동의류 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 167, 'title': '[드시모네]키즈 스텝1 블루베리향 2박스 + 5포 추가증정', 'origin_price': '136000', 'discount_price': '136000', 'discount_percent': 0, 'item_code': '1645931273', 'provider': '드시모네공식'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 168, 'title': '곡물그대로 21 오리지널 100봉 + 자색고구마 100봉 (총 200봉) ', 'origin_price': '30900', 'discount_price': '28500', 'discount_percent': '7', 'item_code': '1667572048', 'provider': '신세계TV쇼핑'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 169, 'title': '[다우니]1+1 다우니 프리미엄 폼형 세탁세제 블루 16개입 +사은', 'origin_price': '51900', 'discount_price': '38930', 'discount_percent': '24', 'item_code': '1821528773', 'provider': '다우니'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 170, 'title': '조혜경 조리기능장 [죽순] 영계탕 8팩 (7.2kg)_삼계탕', 'origin_price': '50900', 'discount_price': '50900', 'discount_percent': 0, 'item_code': '2125073238', 'provider': '공영쇼핑TV'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 171, 'title': '[해피바스]화이트클레이모공클렌징폼 150GX4개', 'origin_price': '24900', 'discount_price': '12900', 'discount_percent': '48', 'item_code': '2093605558', 'provider': '해피바스'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 172, 'title': '[동원참치]라이트 스탠다드 참치 100g 15캔 원터치', 'origin_price': '23900', 'discount_price': '19900', 'discount_percent': '16', 'item_code': '1607527508', 'provider': '동원에프앤비공식'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 173, 'title': '스케치북 도화지 130g 8절 125매 x2개(총250매)', 'origin_price': '21000', 'discount_price': '10500', 'discount_percent': '50', 'item_code': '2030187373', 'provider': '문구/사무용품 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 174, 'title': '[미니케이]국산 7부/반팔/유아/아동/주니어/내의/실내복/잠옷', 'origin_price': '26300', 'discount_price': '7900', 'discount_percent': '69', 'item_code': '1594993736', 'provider': '유아동의류 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 175, 'title': '옛날 할매 들기름 메밀막국수 186.7g 3팩+싸먹는불고기', 'origin_price': '19900', 'discount_price': '9900', 'discount_percent': '50', 'item_code': '2119341693', 'provider': '아빠식당'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 176, 'title': '시크루즈/15%/홈웨어/원피스/바지/빅사이즈/롱원피스', 'origin_price': '39600', 'discount_price': '11900', 'discount_percent': '69', 'item_code': '1430266775', 'provider': '여성의류 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 177, 'title': '[해피바스]씨솔트 딥 클렌징폼 150GX4개', 'origin_price': '24900', 'discount_price': '12900', 'discount_percent': '48', 'item_code': '2093604338', 'provider': '해피바스'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 178, 'title': '[비타민마을]라이프메가 rTG 알티지오메가3 트루 5박스 5개월분', 'origin_price': '21900', 'discount_price': '21470', 'discount_percent': '1', 'item_code': '1807945630', 'provider': '비타민마을공식'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 179, 'title': '[비타민마을]15곡 발효 효소 분말 더블케어 발효 효소 3박스', 'origin_price': '23900', 'discount_price': '23430', 'discount_percent': '1', 'item_code': '2094822130', 'provider': '비타민마을공식'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 180, 'title': '남녀공용 무지티셔츠/나시/아이스팬츠 24종', 'origin_price': '11300', 'discount_price': '3400', 'discount_percent': '69', 'item_code': '2042611280', 'provider': '파라고나'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 181, 'title': '농협 해나루 황토 감자 5kg(대)/개당100~160g/노지/햇', 'origin_price': '7500', 'discount_price': '7500', 'discount_percent': 0, 'item_code': '2133602533', 'provider': '우리네농산물'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 182, 'title': '[SOil](S-OIL) 모바일주유권 5만원/ 실시간발송/ 주유상품권', 'origin_price': '50000', 'discount_price': '49000', 'discount_percent': '2', 'item_code': '1783367530', 'provider': 'SOil'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 183, 'title': '[다우니]다우니 대용량 섬유유연제 아로마플로럴 8.5L 2개', 'origin_price': '99000', 'discount_price': '35900', 'discount_percent': '63', 'item_code': '1606250151', 'provider': '다우니'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 184, 'title': '[JW중외제약]루테인지아잔틴 오메가3 눈건강 눈영양제 루테인 3박스', 'origin_price': '65800', 'discount_price': '29900', 'discount_percent': '54', 'item_code': '774906563', 'provider': 'JW중외제약'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 185, 'title': '[브리타]막스트라 플러스 필터 3개월분', 'origin_price': '25500', 'discount_price': '19000', 'discount_percent': '25', 'item_code': '1992687537', 'provider': '건강/의료용품 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 186, 'title': '[팸퍼스]팸퍼스 2021에어차차 팬티형 5단계 (52 X 3)', 'origin_price': '72000', 'discount_price': '72000', 'discount_percent': 0, 'item_code': '2107049672', 'provider': '출산/육아 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 187, 'title': '[네스카페]수프리모 오리지널 300T', 'origin_price': '28800', 'discount_price': '24900', 'discount_percent': '13', 'item_code': '1676697261', 'provider': '네스카페공식'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 188, 'title': '[비타500]광동제약 비타500 100ml 10입 10개(100병)', 'origin_price': '44900', 'discount_price': '36900', 'discount_percent': '17', 'item_code': '1806530480', 'provider': '광동공식'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 189, 'title': '[케라시스]케라시스 데미지 대용량 샴푸 4000ml +펌프증정', 'origin_price': '25000', 'discount_price': '12500', 'discount_percent': '50', 'item_code': '1515871222', 'provider': '애경공식'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 190, 'title': '[이엑스알]EXR 21SS 여성용 멀티웨어 5종', 'origin_price': '29000', 'discount_price': '28000', 'discount_percent': '3', 'item_code': '2134598769', 'provider': '이엑스알'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 191, 'title': '[에프킬라]에프킬라 리퀴드 무향 리필(45일)x3개 모기약', 'origin_price': '17900', 'discount_price': '11900', 'discount_percent': '33', 'item_code': '1784141891', 'provider': '에프킬라'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 192, 'title': '[진라면]진라면 매운맛 40봉', 'origin_price': '30000', 'discount_price': '19800', 'discount_percent': '34', 'item_code': '1614191721', 'provider': '오뚜기공식'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 193, 'title': '타니즈_여름샌들/뮬/슬리퍼 36종(전 상품 7900 균일)', 'origin_price': '26000', 'discount_price': '7900', 'discount_percent': '69', 'item_code': '1474760371', 'provider': '신발 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 194, 'title': '브리치x한미미 BEST 15%쿠폰 티셔츠/팬츠/스커트', 'origin_price': '48300', 'discount_price': '14500', 'discount_percent': '69', 'item_code': '1787960274', 'provider': 'brich'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 195, 'title': '[아이오페]아이오페 바이오 컨디셔닝 에센스 외', 'origin_price': '86000', 'discount_price': '61920', 'discount_percent': '28', 'item_code': '965932187', 'provider': '아이오페'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 196, 'title': '패션라인15%쿠폰여름블라우스 원피스/티셔츠/빅사이즈', 'origin_price': '43000', 'discount_price': '12900', 'discount_percent': '70', 'item_code': '777247382', 'provider': '여성의류 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 197, 'title': '[일렉트로룩스]18V 무선청소기 ZB3311 AK + 4종 노즐 증정 (BEST)', 'origin_price': '124730', 'discount_price': '124730', 'discount_percent': 0, 'item_code': '1939404339', 'provider': '생활/미용가전 G마켓 베스트'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 198, 'title': '[다우니]다우니 블루 1L 레몬그라스와 달콤한 라일락 향 4개', 'origin_price': '18400', 'discount_price': '14720', 'discount_percent': '20', 'item_code': '1817446983', 'provider': '다우니'}
# {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 199, 'title': '[토니모리]중복쿠폰20%+~72% 토니모리 여름맞이 쇼킹한 369 특가', 'origin_price': '40000', 'discount_price': '15000', 'discount_percent': '62', 'item_code': '747614965', 'provider': '토니모리공식'}
# ...
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 40, 'title': '[이고진] 스텝퍼 계단오르기 운동 블랙핑크 (8320)', 'origin_price': '48980', 'discount_price': '48980', 'discount_percent': 0, 'item_code': '2130147671', 'provider': '휘트니스/수영 G마켓 베스트'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 41, 'title': '[컬럼비아](광주신세계)컬럼비아 남성 팔머스톤 기능성 반바지(AE4366)', 'origin_price': '30000', 'discount_price': '24000', 'discount_percent': '20', 'item_code': '1808836883', 'provider': '등산/아웃도어 G마켓 베스트'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 42, 'title': '2+1 자외선차단 패치 햇빛차단테이프 골프패치', 'origin_price': '50000', 'discount_price': '50000', 'discount_percent': 0, 'item_code': '1993325869', 'provider': '골프 G마켓 베스트'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 43, 'title': '[아디다스]아디다스 본사델팔라 /FY7467', 'origin_price': '41400', 'discount_price': '41400', 'discount_percent': 0, 'item_code': '2070368803', 'provider': '아디다스공식'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 44, 'title': '[머렐]머렐본사티셔츠 폴로티 경량자켓 기획 17%추가할인', 'origin_price': '46000', 'discount_price': '17900', 'discount_percent': '61', 'item_code': '2005402051', 'provider': '등산/아웃도어 G마켓 베스트'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 45, 'title': '마이크로킥보드_스쿠터 스피드', 'origin_price': '209000', 'discount_price': '202730', 'discount_percent': '3', 'item_code': '1821680128', 'provider': '자전거/보드/기타레저 G마켓 베스트'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 46, 'title': '마추픽추 롱 릴렉스 체어 특대 2개 세트 캠핑의자 1+1', 'origin_price': '59900', 'discount_price': '59550', 'discount_percent': 0, 'item_code': '1267548326', 'provider': '캠핑/낚시 G마켓 베스트'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 47, 'title': '[크록스]크록스 W몰 크록밴드 키즈 베스트 3가지컬러 (20453', 'origin_price': '34900', 'discount_price': '34280', 'discount_percent': '1', 'item_code': '1766298492', 'provider': '크록스'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 48, 'title': '[아디다스]아디다스/나이키 외 인기 트레이닝복 상하세트 모음전', 'origin_price': '61600', 'discount_price': '18500', 'discount_percent': '69', 'item_code': '1909900724', 'provider': '아디다스'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 49, 'title': '[디스커버리][디스커버리]여름 반팔티/래쉬가드 외 BIG 세일전', 'origin_price': '35360', 'discount_price': '35360', 'discount_percent': 0, 'item_code': '2139499018', 'provider': '휘트니스/수영 G마켓 베스트'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 50, 'title': '[나이키]나이키 스우시 크루삭스 3팩 6팩 드라이핏 스포츠양말', 'origin_price': '10000', 'discount_price': '9900', 'discount_percent': '1', 'item_code': '1927705175', 'provider': '골프 G마켓 베스트'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 51, 'title': '(1 + 1) 릴렉시즘 항균 쿨마스크', 'origin_price': '11900', 'discount_price': '11900', 'discount_percent': 0, 'item_code': '2104262358', 'provider': '주식회사블랙홀릭'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 52, 'title': '[아디다스]아디다스 본사코어레이서 /FX3592', 'origin_price': '38500', 'discount_price': '38500', 'discount_percent': 0, 'item_code': '2077814727', 'provider': '아디다스공식'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 53, 'title': '[올포유]여름 인기 데일리룩~고객상품평 최고 UP TO 88%OFF', 'origin_price': '63300', 'discount_price': '19000', 'discount_percent': '69', 'item_code': '1798924338', 'provider': '골프 G마켓 베스트'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 54, 'title': '[컬럼비아]남녀 시프트 브리즈 멀티트레킹화 BM0081 BL0081 BM1037 JS', 'origin_price': '63000', 'discount_price': '45360', 'discount_percent': '28', 'item_code': '1867187435', 'provider': '등산/아웃도어 G마켓 베스트'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 55, 'title': '[휠라][휠라 슈즈] 서피 샌들 4종 택1 (1SM01583D_SKU)', 'origin_price': '49000', 'discount_price': '48020', 'discount_percent': '2', 'item_code': '2127405996', 'provider': '휠라'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 56, 'title': '[엠피온]엠피온 SET-525 무선하이패스 단말기 태양광거치대포함', 'origin_price': '59900', 'discount_price': '59900', 'discount_percent': 0, 'item_code': '657750071', 'provider': '자동차용품 G마켓 베스트'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 57, 'title': '나이키프로쿨컴프레션남자레깅스타이즈 703098-010', 'origin_price': '29900', 'discount_price': '29900', 'discount_percent': 0, 'item_code': '1783600712', 'provider': 'HO무역'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 58, 'title': '[뮬라웨어]17% 뮬라웨어 스포츠위크 BEST Vol.2', 'origin_price': '29000', 'discount_price': '18400', 'discount_percent': '36', 'item_code': '2038118952', 'provider': '휘트니스/수영 G마켓 베스트'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 59, 'title': '장마 태풍도 버티는 24개살 우산 1+1 최고급 우산 1+1', 'origin_price': '19900', 'discount_price': '17400', 'discount_percent': '12', 'item_code': '2128386891', 'provider': '골프 G마켓 베스트'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 60, 'title': '[카렉스]레인스톰 하이브리드 와이퍼  2+2 2세트 무료배송', 'origin_price': '11900', 'discount_price': '11900', 'discount_percent': 0, 'item_code': '1505154129', 'provider': '자동차용품 G마켓 베스트'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 61, 'title': '[크러시온]KC인증제품 확장형 코일매트 코일카매트 자동차매트', 'origin_price': '28000', 'discount_price': '26550', 'discount_percent': '5', 'item_code': '783636386', 'provider': '자동차용품 G마켓 베스트'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 62, 'title': '카멜레온360 송풍구형 블랙 차량용 핸드폰 거치대', 'origin_price': '16200', 'discount_price': '15580', 'discount_percent': '3', 'item_code': '1255745943', 'provider': '자동차용품 G마켓 베스트'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 63, 'title': '[한솔]1분 자동충전매트 더블 차박 에어매트 자충 캠핑 매트', 'origin_price': '79800', 'discount_price': '79800', 'discount_percent': 0, 'item_code': '2140644229', 'provider': '캠핑/낚시 G마켓 베스트'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 64, 'title': '[훼르자]남녀공용 훼르자 SUB 3 마라톤 런닝화 4종', 'origin_price': '40000', 'discount_price': '15900', 'discount_percent': '60', 'item_code': '1850649103', 'provider': '훼르자'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 65, 'title': '아큘레틱 초특가 아쿠아슈즈 워터파크 워터슈즈', 'origin_price': '22240', 'discount_price': '11120', 'discount_percent': '50', 'item_code': '973325059', 'provider': '아큘레틱공식몰'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 66, 'title': '[리복](신세계본점)리복 캐주얼 기능성 워킹화 트레킹화 G55450 GV7097 GV7098 GV7101 FX1422 FX1423 REEBOK W...', 'origin_price': '39000', 'discount_price': '30640', 'discount_percent': '21', 'item_code': '2136828908', 'provider': '리복'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 67, 'title': '신수지의 밸런스코어 훌라후프 GOOD-V10', 'origin_price': '29800', 'discount_price': '29800', 'discount_percent': 0, 'item_code': '2000567271', 'provider': '휘트니스/수영 G마켓 베스트'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 68, 'title': '로티캠프 원터치텐트+탈착식 헥사타프', 'origin_price': '104000', 'discount_price': '104000', 'discount_percent': 0, 'item_code': '2078997361', 'provider': '캠핑/낚시 G마켓 베스트'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 69, 'title': 'CJ단독 선공개 내셔널지오그래픽 21SS 어반쉐이드V3 그늘막텐트', 'origin_price': '119000', 'discount_price': '119000', 'discount_percent': 0, 'item_code': '2142895477', 'provider': '캠핑/낚시 G마켓 베스트'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 70, 'title': '[이화에스엠피]리퍼 NEW 쉐이크보드 진동운동기', 'origin_price': '148000', 'discount_price': '148000', 'discount_percent': 0, 'item_code': '1774667597', 'provider': '휘트니스/수영 G마켓 베스트'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 71, 'title': '5매 쿨 3매 구리 숨쉬기 편한 스포츠 항균 마스크', 'origin_price': '13900', 'discount_price': '13900', 'discount_percent': 0, 'item_code': '1984578296', 'provider': 'IM_스토어'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 72, 'title': '[카르닉]랜턴스탠드 캠핑용품 캠핑 랜턴 걸이 투웨이 4단', 'origin_price': '24900', 'discount_price': '22120', 'discount_percent': '11', 'item_code': '1857892798', 'provider': '캠핑/낚시 G마켓 베스트'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 73, 'title': '[휠라]온라인 단독  Sun 반팔티셔츠 FE2RSD5124XBLK', 'origin_price': '32000', 'discount_price': '32000', 'discount_percent': 0, 'item_code': '2127311048', 'provider': '휠라공식'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 74, 'title': '[타미힐피거]타미힐피거 여성 카라 민소매 원피스 7종', 'origin_price': '41500', 'discount_price': '12450', 'discount_percent': '70', 'item_code': '2096204420', 'provider': '타미힐피거'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 75, 'title': '[BUFFALO]버팔로 H슬림체어 1+1 캠핑의자 접이식의자 캠핑용품', 'origin_price': '31800', 'discount_price': '27900', 'discount_percent': '12', 'item_code': '1649361309', 'provider': '캠핑/낚시 G마켓 베스트'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 76, 'title': '[텐제로]20%쿠폰 5520원 균일가 반팔티/여름바지/반바지', 'origin_price': '13800', 'discount_price': '6900', 'discount_percent': '50', 'item_code': '1568593417', 'provider': '텐제로'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 77, 'title': '[멜킨스포츠]EVA폼롤러 원형 91cm 요가 필라테스 마사지 홈트 용품', 'origin_price': '22900', 'discount_price': '22580', 'discount_percent': '1', 'item_code': '807880576', 'provider': '휘트니스/수영 G마켓 베스트'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 78, 'title': '[웨스트우드]웨스트우드 SUMMER티셔츠/조끼/팬츠 세일전', 'origin_price': '49000', 'discount_price': '15000', 'discount_percent': '69', 'item_code': '1770086331', 'provider': '웨스트우드공식'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 79, 'title': '[더룩]가려보까 차량용 햇빛가리개 블라인드 1+1', 'origin_price': '10900', 'discount_price': '10900', 'discount_percent': 0, 'item_code': '1652851169', 'provider': '자동차용품 G마켓 베스트'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 80, 'title': '[패스트캠프]오페라3 원터치 텐트 3~4인용 팝업텐트', 'origin_price': '49900', 'discount_price': '44910', 'discount_percent': '10', 'item_code': '1470979464', 'provider': '캠핑/낚시 G마켓 베스트'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 81, 'title': '[마이크로킥보드]마이크로킥보드 미니 핸드 디럭스 LED 레드', 'origin_price': '154000', 'discount_price': '149380', 'discount_percent': '3', 'item_code': '1587861554', 'provider': '자전거/보드/기타레저 G마켓 베스트'}
# {'category_name': '패션의류', 'sub_category_name': '스포츠/자동차', 'ranking': 82, 'title': '[네파]네파 K2 블랙야크 쿨토시 팔토시 쿨스카프 여름 토시', 'origin_price': '5430', 'discount_price': '5430', 'discount_percent': 0, 'item_code': '1626858208', 'provider': '네파'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-8a8f37301504> in <module>
#      51 for category in categories:
#      52     # print('http://corners.gmarket.co.kr' + category['href'], category.get_text())
# ---> 53     get_category('http://corners.gmarket.co.kr' + category['href'], category.get_text())
#
# <ipython-input-5-52ec1b189b8a> in get_category(category_link, category_name)
#      11         res = requests.get('http://corners.gmarket.co.kr' + sub_category['href'])
#      12         soup = BeautifulSoup(res.content, 'html.parser')
# ---> 13         get_items(soup, category_name, sub_category.get_text())
#      14         # print(category_link, category_name, sub_category.get_text(), 'http://corners.gmarket.co.kr' + sub_category['href'])
#
# <ipython-input-4-f87c5d54831a> in get_items(html, category_name, sub_category_name)
#      34             item_code = product_link.attrs['href'].split('=')[1].split('&')[0]
#      35
# ---> 36             res = requests.get(product_link.attrs['href'])
#      37             soup = BeautifulSoup(res.content, 'html.parser')
#      38             provider = soup.select_one('div.item-topinfo_headline > p > span')
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# C:\ProgramData\Anaconda3\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# C:\ProgramData\Anaconda3\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# C:\ProgramData\Anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
def get_category(category_link, category_name):
    res = requests.get(category_link)
    soup = BeautifulSoup(res.content, "html.parser")
    
    # print(category_link, category_name)
    
    # get_items(soup, category_name, "ALL")
    
    sub_categories = soup.select('div.gbest-cate div.cate-l div.navi.group ul li a')
    for sub_category in categories:
        res = requests.get('http://corners.gmarket.co.kr' + sub_category['href']) 
        soup = BeautifulSoup(res.content, 'html.parser')
        get_items(soup, category_name, sub_category.get_text())
        # print(category_link, category_name, sub_category.get_text(), 'http://corners.gmarket.co.kr' + sub_category['href'])

# %%
import sys
print(sys.executable)
print(sys.path)
# Out:
# C:\ProgramData\Anaconda3\python.exe
# ['C:\\Users\\ktb58\\OneDrive\\바탕 화면\\ML_lecture\\day06', 'C:\\ProgramData\\Anaconda3\\python38.zip', 'C:\\ProgramData\\Anaconda3\\DLLs', 'C:\\ProgramData\\Anaconda3\\lib', 'C:\\ProgramData\\Anaconda3', '', 'C:\\ProgramData\\Anaconda3\\lib\\site-packages', 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\win32', 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\win32\\lib', 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\Pythonwin', 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\ktb58\\.ipython']

# %%
#main/sub category + 상품 정보 수집
import requests
from bs4 import BeautifulSoup

def get_items(html, category_name, sub_category_name):
        items_result_list = list()
        best_item = html.select('div.best-list')
        for idx, item in enumerate(best_item[1].select('li')):
            
            dict_data = dict()
            
            ranking = idx + 1
            title = item.select_one('a.itemname')
            origin_price = item.select_one('div.o-price')
            discount_price = item.select_one('div.s-price strong span')
            discount_percent = item.select_one('div.s-price em')
            
            if origin_price == None or origin_price.get_text() == '':
                origin_price = discount_price
                
            if discount_price == None:
                origin_price, discount_price = 0, 0
            else:
                origin_price = origin_price.get_text().replace(',','').replace('원','')
                discount_price = discount_price.get_text().replace(',','').replace('원','')
            
            if discount_percent == None or discount_percent == '':
                discount_percent = 0
            else:
                discount_percent = discount_percent.get_text().replace('%','')
            
            
            product_link = item.select_one('div.thumb > a')
            item_code = product_link.attrs['href'].split('=')[1].split('&')[0]
            
            res = requests.get(product_link.attrs['href'])
            soup = BeautifulSoup(res.content, 'html.parser')
            provider = soup.select_one('div.item-topinfo_headline > p > span')
            
            if provider == None:
                provider = ''
            else:
                provider = provider.get_text()
                
                
            dict_data['category_name'] = category_name  
            dict_data['sub_category_name'] = sub_category_name
            dict_data['ranking'] = ranking
            dict_data['title'] = title.get_text()
            dict_data['origin_price'] = origin_price
            dict_data['discount_price'] = discount_price       
            dict_data['discount_percent'] = discount_percent 
            dict_data['item_code'] = item_code    
            dict_data['provider'] = provider.replace('\n','')    
            
            print(dict_data)
            
            # print(category_name, sub_category_name, ranking, item_code, provider, title.get_text(), origin_price, discount_price, discount_percent)

# %%
item_info = {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 1, 'title': 'PSK 항공 리얼 생 망고스틴 2kg(20-24과)', 'origin_price': '34900', 'discount_price': '32200', 'discount_percent': '7', 'item_code': '2144050371', 'provider': 'G마켓 베스트'}

sql = """insert into ranking(main_category, sub_category, item_ranking, item_code) values(
'""" + item_info['category_name'] + """', 
'""" + item_info['sub_category_name'] + """', 
""" + str(item_info['ranking']) + """, 
'""" + item_info['item_code'] + """');"""

sql.replace('\n','')
# Out:
# "insert into ranking(main_category, sub_category, item_ranking, item_code) values('ALL', 'ALL', 1, '2144050371');"
