# %%
# main/sub category 정보 수집

import requests
from bs4 import BeautifulSoup

res = requests.get("http://corners.gmarket.co.kr")

soup = BeautifulSoup(res.content, "html.parser")

categories = soup.select('div.gbest-cate ul.by-group li a')

'''
def get_items(html, category_name, sub_category_name):
    items_result_list = list()
    best_item = html.select('div.best-list')
    for idx, item in enumerate(best_item[1].select('li')):
        title = item.select_one('a.itemname')
        origin_price = item.select_one('div.o-price')
        discount_price = item.select_one('div.s-price strong span')
        discount_percent = item.select_one('div.s-price em')

        if origin_price == None or origin_price.get_text() == '':
            origin_price = discount_price

        origin_price = origin_price.get_text().replace(',','').replace('원','')
        discount_price = discount_price.get_text().replace(',','').replace('원','')

        if discount_percent == None or discount_percent == '':
            discount_percent = 0
        else:
            discount_percent = discount_percent.get_text().replace('%','')

        print(category_name, sub_category_name, title.get_text(), origin_price, discount_price, discount_percent) 
        
def get_category(category_link, category_name):
    res = requests.get(category_link)
    soup = BeautifulSoup(res.content, "html.parser")
    
    # print(category_link, category_name)
    
    # get_items(soup, category_name, "ALL")
    
    sub_categories = soup.select('div.gbest-cate div.cate-l div.navi.group ul li a')
    for sub_category in categories:
        res = requests.get('http://corners.gmarket.co.kr' + sub_category['href']) 
        soup = BeautifulSoup(res.content, 'html.parser')
        get_items(soup, category_name, sub_category.get_text())
        print(category_link, category_name, sub_category.get_text(), 'http://corners.gmarket.co.kr' + sub_category['href'])     

'''
for category in categories:
    # print('http://corners.gmarket.co.kr' + category['href'], category.get_text())    
    get_category('http://corners.gmarket.co.kr' + category['href'], category.get_text())
# Out:
# ALL ALL 2144050371
# G마켓 베스트
#  PSK 항공 리얼 생 망고스틴 2kg(20-24과) 34900 32200 7
# ALL ALL 2132159697
# G마켓 베스트
#  [제스프리](M)제스프리 썬골드키위 점보사이즈 3.1kg(과당 156g 내외  19-20과) 30900 28500 7
# ALL ALL 2140618396
# G마켓 베스트
#  [KFC](KFC) 징거앤타워팩 22100 11500 47
# ALL ALL 1605671250
# G마켓 베스트
#  [앱솔루트명작]앱솔루트 명작 3단계 800g 3캔 무료배송 44900 42900 4
# ALL ALL 2140383084
# G마켓 베스트
#  [KB증권](KB증권) 국내주식 이용권 5만원권 50000 50000 0
# ALL ALL 1760714599
# G마켓 베스트
#  완도 손질곰피미역 120gX5팩+갈치속젓 19800 9900 50
# ALL ALL 1842357844
# G마켓 베스트
#  15%중복쿠폰/쿨레깅스/쿨팬츠/롱원피스/빅사이즈~4XL 23000 6900 70
# ALL ALL 2094678315
# G마켓 베스트
#  [롯데제과]빼빼로(초코/아몬드/누드/크런키) 15곽 골라담기 17300 13900 19
# ALL ALL 1932807663
# G마켓 베스트
#  [깨끗한나라]깨끗한나라 벚꽃 프리미엄 화장지 (총90롤) 27mx30롤 36810 30880 16
# ALL ALL 2127268043
# G마켓 베스트
#  [동아오츠카]라인바싸 탄산수 500ml 2박스 ( 20입+20입 ) 13900 13630 1
# ALL ALL 2122431202
# 참도깨비
#  [참도깨비]춘천 식 숯불 닭갈비 750g x 2봉 23400 10500 55
# ALL ALL 2094794152
# 천하일미
#  [천하일미]홍석천 이원일 떡갈비 160g 전통3팩+매콤3팩 (총12장) 27800 12500 55
# ALL ALL 1205483415
# 스포츠의류/운동화 G마켓 베스트
#  [크록스]본사공식 크록스 BEST 29종 택 (G062121) 74950 22490 69
# ALL ALL 1606293717
# (수맘)
#  수맘 여름 신상입고 15%쿠폰 면 홈웨어 잠옷 세트 19600 5900 69
# ALL ALL 1694504111
# 유아동의류 G마켓 베스트
#  [아이더](대구신세계)[아이더](역시즌추가할인)JMF19507 키즈 아동 큐빗 롱다운 롱패딩 63000 50340 20
# ALL ALL 1837778618
# 다우니
#  [다우니]1+1 다우니 프리미엄 폼형 세제 실내건조 16입 +사은품 51900 38930 24
# ALL ALL 2107124794
# 음향기기 G마켓 베스트
#  [애플][국내정품] 애플 에어팟 프로 무선 충전 MWP22KH/A 297000 252450 15
# ALL ALL 1502601299
# 주방용품 G마켓 베스트
#  [스카치 브라이트]베이직 고무장갑 10개 사이즈 선택+집게 증정 31800 15900 50
# ALL ALL 2140324687
# 가공식품 G마켓 베스트
#  [늘바른]이베리코 양념 치마살1kg /2세트구매국산오돌뼈500g증 21900 10900 50
# ALL ALL 2135847830
# 엉클탐
#  소불고기 광양식 250gX3팩/수제비법소스의 깊은 감칠맛 22000 9900 55
# ALL ALL 1655242371
# e쿠폰 G마켓 베스트
#  [구글플레이](카드가능) 기프트코드 10만원 / 구글 기프트카드 100000 95000 5
# ALL ALL 1791759756
# 스카트
#  [스카트]스카트 THE 버블 수세미 그레이 50매X3롤 27000 11900 55
# ALL ALL 1624900645
# 언더웨어 G마켓 베스트
#  [이너리즘]심리스 스포츠 브라탑 4종기획세트/노라인팬티 5종 45000 13500 70
# ALL ALL 2140616286
# e쿠폰 G마켓 베스트
#  [KFC](KFC) 더블치킨세트 12000 6000 50
# ALL ALL 1373777190
# 쉬블림로브
#  쉬블림로브 15%쿠폰 균일가 블라우스 셔츠 상하세트 29600 8900 69
# ALL ALL 1280233513
# T-MEI
#  티메이 15%할인 블라우스 원피스 티셔츠 반팔 32900 9900 69
# ALL ALL 2122330900
# 참도깨비
#  [참도깨비]금강만두 육개장 630g x5봉 33900 16900 50
# ALL ALL 2137965030
# 멸치쇼핑
#  2021년 첫 출하 의성 군위 대석 자두 3kg/소과 25-40g내외 11500 10350 10
# ALL ALL 1808836883
# 등산/아웃도어 G마켓 베스트
#  [컬럼비아](광주신세계)컬럼비아 남성 팔머스톤 기능성 반바지(AE4366) 30000 24000 20
# ALL ALL 1837767492
# 다우니
#  [다우니]다우니 프리미엄 액체형 세탁세제 실내건조 2.8L 2개 32900 24680 24
# ALL ALL 2124077426
# 생활/미용가전 G마켓 베스트
#  [브라운](현대백화점)브라운 3시리즈 전기면도기 310S 47700 44840 5
# ALL ALL 2118721967
# e쿠폰 G마켓 베스트
#  [한국투자증권](한국투자증권) 온라인 금융상품권 50000원권 50000 50000 0
# ALL ALL 1645930937
# 건강식품 G마켓 베스트
#  [미래생활]미래생활 순수PURE천연펄프 25m 30롤 x 3팩 31900 26900 15
# ALL ALL 185126914
# 트라이
#  [트라이]아동팬티 5매 세트 /남아/여아/속옷/런닝/유아/주니어 23000 6900 70
# ALL ALL 2140732651
# 대한농산(G)
#  대한농산 천도 복숭아 3kg내외(40과내외) 9900 9710 1
# ALL ALL 1828312825
# 러브쿡
#  [러브쿡]스텐 국수냄비 18cm (깊은형)/ 파스타냄비 육수냄비 19800 9900 50
# ALL ALL 1797053808
# 생필품 G마켓 베스트
#  [크리넥스]크리넥스 실크소프트 250매X3입X3팩 /곽티슈 27000 16900 37
# ALL ALL 1487777111
# 가방/잡화 G마켓 베스트
#  국산 10켤레 남자양말 패션 발목 덧신 중목 신사 정장 21000 6400 69
# ALL ALL 1909900945
# 동원에프앤비
# 공식
#  [리챔]리챔 200g x 10캔 + 리챔 120g x 1캔 20780 18700 10
# ALL ALL 1783303725
# 크리넥스
#  [크리넥스안심]유한킴벌리 안심 클래식 키친타올 140매x12롤X2팩 27000 18900 30
# ALL ALL 1645927108
# 드시모네
# 공식
#  [드시모네]캡슐 1박스 60캡슐(2개월분) 118000 118000 0
# ALL ALL 1614192635
# 오뚜기
# 공식
#  [진라면]진라면 순한맛 20봉+매운맛20봉 30000 18800 37
# ALL ALL 2135690531
# 밀레
#  [밀레](대구신세계)[밀레]역시즌 여성 폭스퍼 셀레네W 구스 다운(MXPWD663)[출시 최초가 388 000원] 99000 74250 25
# ALL ALL 1827756830
# 천호엔케어
# 공식
#  [천호엔케어]콜라겐 담은 석류젤리 14포x4박스 총56포/장윤정콜라겐 53000 29900 43
# ALL ALL 2137892100
# 아디다스키즈
#  [아디다스키즈](신세계강남점)[adidas kidss]SUPERSTAR 360 I(Q46306) 59000 44840 24
# ALL ALL 2104309832
# 더틸버리
#  [더틸버리](더틸버리) 오버핏 체크 시어서커 원피스 TL6N0OP62 31200 31200 0
# ALL ALL 1765233891
# 신발 G마켓 베스트
#  보가수제화 여름 신상 샌들/뮬/슬리퍼/조리 33000 9900 70
# ALL ALL 1578966236
# 롯데칠성
# 공식
#  [칠성사이다]칠성 사이다 210ml x 30캔 15900 11500 27
# ALL ALL 2104253380
# 레노마키즈
# 공식
#  [레노마키즈]레노마키즈 페리미츠 여름 이월 티셔츠 팬츠 70종 33000 10000 69
# ALL ALL 1747435299
# 스마일배송
#  국내산 무형광천연펄프 엑소 종이컵 1000개  사업자 11000 11000 0
# ALL ALL 2133708741
# 건강/의료용품 G마켓 베스트
#  [유한킴벌리]크리넥스 비말차단 라이트핏 쿨마스크 대형 50p(1BOX) 39900 26900 32
# ALL ALL 2110863137
# 신세계TV쇼핑
#  [햇반](빠른배송) CJ 햇반 190g 36개 32700 32100 1
# ALL ALL 1289510185
# 바디/헤어 G마켓 베스트
#  [과일나라]진주펄 염색약 3개 /12종 컬러 염색/새치/탈색약 28900 8900 69
# ALL ALL 1911171606
# 글라스락
# 공식
#  [글라스락]글라스락 간편쿡용기 1.2L 2조 29800 14900 50
# ALL ALL 1558860840
# 슈퍼맨푸드
#  순살 치킨 가라아게1kg / 치킨/너겟/간식 1+1 (총2kg) 28700 12900 55
# ALL ALL 1808857191
# 신발 G마켓 베스트
#  신상 여성샌들 여성슬리퍼 여자 샌들 슬리퍼 여름샌들 33000 9900 70
# ALL ALL 2084042826
# 아워홈
#  [아워홈]지리산수 핑크 500ml 80병 /생수전문배송 24500 15840 35
# ALL ALL 2084038788
# 커피/음료 G마켓 베스트
#  [아워홈]지리산수 핑크 500ml 20병 /생수전문배송 6100 3970 34
# ALL ALL 2095685860
# 유한킴벌리
# 공식
#  [유한킴벌리]크리넥스3겹 데코소프트33MX24롤X2팩 49000 32900 32
# ALL ALL 2128272385
# 여성의류 G마켓 베스트
#  로코코  15% 여름신상 원피스/블라우스 33000 9900 70
# ALL ALL 2001447494
# 화장품/향수 G마켓 베스트
#  [에뛰드]6월 SALE 순정 40% 메이크업 50% 50000 25000 50
# ALL ALL 2060835461
# 신발 G마켓 베스트
#  말랑말랑 컬러 실내 쿠션 슬리퍼 1+1 거실화/욕실화 33000 9900 70
# ALL ALL 1655241628
# 구글플레이
#  [구글플레이](카드가능) 기프트코드 3만원 / 구글 기프트카드 30000 28500 5
# ALL ALL 1920642031
# 맥심
#  [맥심]모카골드 커피믹스 180T+180T : 쿠폰가 36500원~ 56500 39500 30
# ALL ALL 1821519273
# 헬로
# 공식
#  [헬로]헬로 순수 3겹 천연펄프 화장지 30m 30롤 3팩 특가행사 86700 28900 66
# ALL ALL 1103688403
# 맥심
#  [맥심]화이트골드 커피믹스 180Tx2 +사은품랜덤/쿠폰가34500 53600 37500 30
# ALL ALL 1583658466
# 강블리
#  [강블리]블링 휴 3겹 무형광 롤화장지 30M 30롤 2팩 47700 15900 66
# ALL ALL 801692869
# CJ온스타일
#  [스와들업] 신생아 속싸개 뱀부라이트_가볍고부드러운 뱀부원단 68000 38900 42
# ALL ALL 1505743733
# 바디/헤어 G마켓 베스트
#  [세타필]세타필 대용량1+1(로션 473ml+로션 473ml) +사은품3종 39000 23900 38
# ALL ALL 1464560778
# 반려동물용품 G마켓 베스트
#  [프로베스트]프로베스트캣 블루 20kg  / 무료배송 / 박스포장 31500 31500 0
# ALL ALL 1645922945
# 드시모네
# 공식
#  [드시모네]키즈 스텝1 블루베리  1박스 30포(30일분) 68000 68000 0
# ALL ALL 2140489832
# NS홈쇼핑
#  하림이닭 삼계탕 6팩 45900 45900 0
# ALL ALL 1277558140
# 가방/잡화 G마켓 베스트
#  [프롬산타]3+1 봄 신상 면 덧신/양말/스타킹 남자여자발목학생 23000 6900 70
# ALL ALL 1917857271
# 브랜드 진/캐쥬얼 G마켓 베스트
#  [행텐]누구나17% 행텐 루니툰즈티셔츠독점판매+최대90%SALE 29600 8900 69
# ALL ALL 1704376711
# 스마일배송
#  2박스 대용량 커피크래커 커피과자 쿠키 10900 8900 18
# ALL ALL 2139641345
# CJ온스타일
#  파스쿠찌 쿨링백 증정  파스쿠찌 커피 6입 택1 아메리카노/라떼 15900 15900 0
# ALL ALL 1517719492
# 메이킹유
#  쿠폰15% 원피스/블라우스/여름니트/가디건 빅사이즈 33000 9900 70
# ALL ALL 983183427
# 현대Hmall
#  [동원에프앤비](현대Hmall)[동원]샘물 2L x 총 36병 /생수 17900 17640 1
# ALL ALL 1946636544
# 비룡소
#  [비룡소]비룡소 사각사각 그림책 (전25권) 265770 239200 9
# ALL ALL 447292392
# 맥심
#  [카누]카누 미니 마일드 120Tx2개 총240T: 공유의 작은카페~ 49900 34900 30
# ALL ALL 1780733427
# 맥심
#  [맥심]맥심 모카골드 마일드 180T+180T +텀블러+쿠폰가36500 56500 39500 30
# ALL ALL 1817538454
# 다우니
#  [다우니]다우니 엑스퍼트 실내 건조 1L 6개 +사은품 39800 31840 20
# ALL ALL 2096204420
# 타미힐피거
#  [타미힐피거]타미힐피거 여성 카라 민소매 원피스 7종 41500 12450 70
# ALL ALL 1645917783
# 드시모네
# 공식
#  [드시모네]베이비 캡슐 1박스(30일분) 38000 38000 0
# ALL ALL 2104268165
# 누리푸드
#  (누리푸드)한번도 얼리지않은 눈꽃살치살 250gX2팩 25600 17900 30
# ALL ALL 2122075872
# 매일유업
# 공식
#  [매일유업]매일두유 고단백 190ml 48팩 +포토카드 33500 26500 20
# ALL ALL 2134680693
# 테마북짱
#  (명왕성은자유다) 수학식당 시리즈 (전3권) 36000 33600 6
# ALL ALL 1757179931
# 숲속의하루
#  무형광 5000매핸드타올 C 업소용 가정용 다용도 대용량 21120 21120 0
# ALL ALL 153279336
# 문구/사무용품 G마켓 베스트
#  [박스포유]100%직접생산/ 박스포유 택배박스 32300 29840 7
# ALL ALL 2088091398
# 리빙amc
#  데이데이 생리대 롱팬티라이너 16p x6팩 12800 3900 69
# ALL ALL 2104368705
# brich
#  브리치X저스트원 BEST 15%쿠폰 셔츠/팬츠/스커트 44600 13400 69
# ALL ALL 1383578038
# 여성의류 G마켓 베스트
#  홈쇼핑 썸머세일 린넨/원피스/티셔츠 4900~ 33000 9900 70
# ALL ALL 805485741
# 남성의류 G마켓 베스트
#  [슈프림]15%쿠폰 오버핏 반팔티 남성티셔츠 남자여성 빅사이즈 29600 8900 69
# ALL ALL 1779187574
# 코디
# 공식
#  [코디]허브가든 3겹 화장지 27m 30롤 3팩 휴지 83100 27700 66
# ALL ALL 858294811
# 홍천철원물류센터2
#  황금미가 쌀 20kg 20년산 (당일도정) 58900 54900 6
# ALL ALL 1503353718
# 오뚜기
# 공식
#  [오뚜기밥]맛있는 오뚜기밥 210g 24개 31900 28280 11
# ALL ALL 1536107828
# GS수퍼마켓
#  [GS수퍼마켓](GS THE FRESH)금액상품권3만원 30000 28500 5
# ALL ALL 1567169398
# GNM자연의품격
# 공식
#  [GNM자연의품격]칼슘 마그네슘 아연 비타민D 2통/6개월분 25900 19900 23
# ALL ALL 1495296156
# 문구/사무용품 G마켓 베스트
#  [미스터카피]미스터카피 A4 복사용지 A4용지 75g 2500매 2박스 34760 29900 13
# ALL ALL 1687622836
# ALL 패션의류 1583097834
# 여성의류 G마켓 베스트
#  브리치x아이미마인 BEST 15%쿠폰 셔츠/팬츠/원피스 49600 14900 69
# ALL 패션의류 777247382
# 여성의류 G마켓 베스트
#  패션라인15%쿠폰여름블라우스 원피스/티셔츠/빅사이즈 43000 12900 70
# ALL 패션의류 663211580
# 남성의류 G마켓 베스트
#  (15%쿠폰)M~4XL 남여 쿨론티/면 반팔/기능성/빅사이즈 23000 6900 70
# ALL 패션의류 1430266775
# 여성의류 G마켓 베스트
#  시크루즈/15%/홈웨어/원피스/바지/빅사이즈/롱원피스 39600 11900 69
# ALL 패션의류 972418391
# 언더웨어 G마켓 베스트
#  [BYC]15%쿠폰/여성팬티/위생/노라인/면/보정/나시/속바지 23000 6900 70
# ALL 패션의류 1517719492
# 메이킹유
#  쿠폰15% 원피스/블라우스/여름니트/가디건 빅사이즈 33000 9900 70
# ALL 패션의류 1606293717
# (수맘)
#  수맘 여름 신상입고 15%쿠폰 면 홈웨어 잠옷 세트 19600 5900 69
# ALL 패션의류 805485741
# 남성의류 G마켓 베스트
#  [슈프림]15%쿠폰 오버핏 반팔티 남성티셔츠 남자여성 빅사이즈 29600 8900 69
# ALL 패션의류 189842449
# 요즘에
#  요즘에/썸머신상+15%/청바지/슬랙스/린넨/반바지/3XL~ 33000 9900 70

# %%
def get_category(category_link, category_name):
    res = requests.get(category_link)
    soup = BeautifulSoup(res.content, "html.parser")
    
    # print(category_link, category_name)
    
    # get_items(soup, category_name, "ALL")
    
    sub_categories = soup.select('div.gbest-cate div.cate-l div.navi.group ul li a')
    for sub_category in categories:
        res = requests.get('http://corners.gmarket.co.kr' + sub_category['href']) 
        soup = BeautifulSoup(res.content, 'html.parser')
        get_items(soup, category_name, sub_category.get_text())
        # print(category_link, category_name, sub_category.get_text(), 'http://corners.gmarket.co.kr' + sub_category['href'])

# %%
#main/sub category + 상품 정보 수집
import requests
from bs4 import BeautifulSoup

def get_items(html, category_name, sub_category_name):
        items_result_list = list()
        best_item = html.select('div.best-list')
        for idx, item in enumerate(best_item[1].select('li')):
            title = item.select_one('a.itemname')
            origin_price = item.select_one('div.o-price')
            discount_price = item.select_one('div.s-price strong span')
            discount_percent = item.select_one('div.s-price em')
            
            if origin_price == None or origin_price.get_text() == '':
                origin_price = discount_price
                
            if discount_price == None:
                origin_price, discount_price = 0, 0
            else:
                origin_price = origin_price.get_text().replace(',','').replace('원','')
                discount_price = discount_price.get_text().replace(',','').replace('원','')
            
            if discount_percent == None or discount_percent == '':
                discount_percent = 0
            else:
                discount_percent = discount_percent.get_text().replace('%','')
            
            
            product_link = item.select_one('div.thumb > a')
            item_code = product_link.attrs['href'].split('=')[1].split('&')[0]
            
            res = requests.get(product_link.attrs['href'])
            soup = BeautifulSoup(res.content, 'html.parser')
            provider = soup.select_one('div.item-topinfo_headline > p > span')
            
            if provider == None:
                provider = ''
            else:
                provider = provider.get_text()
            
            print(category_name, sub_category_name, item_code, provider, title.get_text(), origin_price, discount_price, discount_percent)
